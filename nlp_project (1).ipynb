# %%
import warnings
warnings.filterwarnings('ignore')
import pickle
import numpy as np
import pandas as pd
import json

from textblob import TextBlob
import nltk
from scipy import spatial
import torch
import spacy
en_nlp = spacy.load('en_core_web_sm')

# %%
train = pd.read_json(r"/content/drive/MyDrive/train-v1.1.json")

# %%
contexts = []
questions = []
answers_text = []
answers_start = []
for i in range(train.shape[0]):
    topic = train.iloc[i,0]['paragraphs']
    for sub_para in topic:
        for q_a in sub_para['qas']:
            questions.append(q_a['question'])
            answers_start.append(q_a['answers'][0]['answer_start'])
            answers_text.append(q_a['answers'][0]['text'])
            contexts.append(sub_para['context'])
df = pd.DataFrame({"context":contexts, "question": questions, "answer_start": answers_start, "text": answers_text})

# %%
paras = list(df["context"].drop_duplicates().reset_index(drop= True))

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df
# Out:
#                                                  context  \
# 0      Architecturally, the school has a Catholic cha...
# 1      Architecturally, the school has a Catholic cha...
# 2      Architecturally, the school has a Catholic cha...
# 3      Architecturally, the school has a Catholic cha...
# 4      Architecturally, the school has a Catholic cha...
# ...                                                  ...
# 87594  Kathmandu Metropolitan City (KMC), in order to...
# 87595  Kathmandu Metropolitan City (KMC), in order to...
# 87596  Kathmandu Metropolitan City (KMC), in order to...
# 87597  Kathmandu Metropolitan City (KMC), in order to...
# 87598  Kathmandu Metropolitan City (KMC), in order to...
#
#                                                 question  answer_start  \
# 0      To whom did the Virgin Mary allegedly appear i...           515
# 1      What is in front of the Notre Dame Main Building?           188
# 2      The Basilica of the Sacred heart at Notre Dame...           279
# 3                      What is the Grotto at Notre Dame?           381
# 4      What sits on top of the Main Building at Notre...            92
# ...                                                  ...           ...
# 87594  In what US state did Kathmandu first establish...           229
# 87595               What was Yangon previously known as?           414
# 87596  With what Belorussian city does Kathmandu have...           476
# 87597  In what year did Kathmandu create its initial ...           199
# 87598                      What is KMC an initialism of?             0
#
#                                           text
# 0                   Saint Bernadette Soubirous
# 1                    a copper statue of Christ
# 2                            the Main Building
# 3      a Marian place of prayer and reflection
# 4           a golden statue of the Virgin Mary
# ...                                        ...
# 87594                                   Oregon
# 87595                                  Rangoon
# 87596                                    Minsk
# 87597                                     1975
# 87598              Kathmandu Metropolitan City
#
# [87599 rows x 4 columns]

# %%
df['sentences'] = df['context'].apply(lambda x: [item.raw for item in TextBlob(x).sentences])

# %%
data=df

# %%
def get_target(x):
    idx = -1
    for i in range(len(x["sentences"])):
        if x["text"] in x["sentences"][i]: idx = i
    return idx

# %%
data["target"] = data.apply(get_target, axis = 1)

# %%
def get_text(x):
  r= x['target']
  s=x['sentences']
  return s[r]

# %%
data["answer text"] = data.apply(get_text, axis = 1)

# %%
data.head(2)
# Out:
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
#
#                                             question  answer_start  \
# 0  To whom did the Virgin Mary allegedly appear i...           515
# 1  What is in front of the Notre Dame Main Building?           188
#
#                          text  \
# 0  Saint Bernadette Soubirous
# 1   a copper statue of Christ
#
#                                            sentences  target  \
# 0  [Architecturally, the school has a Catholic ch...       5
# 1  [Architecturally, the school has a Catholic ch...       2
#
#                                          answer text
# 0  It is a replica of the grotto at Lourdes, Fran...
# 1  Immediately in front of the Main Building and ...

# %%
from gensim.models import KeyedVectors
word2vec_model_path = r"/content/drive/MyDrive/GoogleNews-vectors-negative300.bin.gz"
word2vec_model = KeyedVectors.load_word2vec_format(word2vec_model_path, binary=True)

# %%
def embed_text(text, model):
    words = text.lower().split()
    vectors = [model[word] for word in words if word in model]
    return sum(vectors) / len(vectors) if vectors else None

# %%
data['question_word2vec'] = data['question'].apply(lambda x: embed_text(x, word2vec_model))
data['answer_word2vec'] = data['answer text'].apply(lambda x: embed_text(x, word2vec_model))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
data
# Out:
#                                                  context  \
# 0      Architecturally, the school has a Catholic cha...
# 1      Architecturally, the school has a Catholic cha...
# 2      Architecturally, the school has a Catholic cha...
# 3      Architecturally, the school has a Catholic cha...
# 4      Architecturally, the school has a Catholic cha...
# ...                                                  ...
# 87594  Kathmandu Metropolitan City (KMC), in order to...
# 87595  Kathmandu Metropolitan City (KMC), in order to...
# 87596  Kathmandu Metropolitan City (KMC), in order to...
# 87597  Kathmandu Metropolitan City (KMC), in order to...
# 87598  Kathmandu Metropolitan City (KMC), in order to...
#
#                                                 question  answer_start  \
# 0      To whom did the Virgin Mary allegedly appear i...           515
# 1      What is in front of the Notre Dame Main Building?           188
# 2      The Basilica of the Sacred heart at Notre Dame...           279
# 3                      What is the Grotto at Notre Dame?           381
# 4      What sits on top of the Main Building at Notre...            92
# ...                                                  ...           ...
# 87594  In what US state did Kathmandu first establish...           229
# 87595               What was Yangon previously known as?           414
# 87596  With what Belorussian city does Kathmandu have...           476
# 87597  In what year did Kathmandu create its initial ...           199
# 87598                      What is KMC an initialism of?             0
#
#                                           text  \
# 0                   Saint Bernadette Soubirous
# 1                    a copper statue of Christ
# 2                            the Main Building
# 3      a Marian place of prayer and reflection
# 4           a golden statue of the Virgin Mary
# ...                                        ...
# 87594                                   Oregon
# 87595                                  Rangoon
# 87596                                    Minsk
# 87597                                     1975
# 87598              Kathmandu Metropolitan City
#
#                                                sentences  target  \
# 0      [Architecturally, the school has a Catholic ch...       5
# 1      [Architecturally, the school has a Catholic ch...       2
# 2      [Architecturally, the school has a Catholic ch...       3
# 3      [Architecturally, the school has a Catholic ch...       4
# 4      [Architecturally, the school has a Catholic ch...       1
# ...                                                  ...     ...
# 87594  [Kathmandu Metropolitan City (KMC), in order t...       1
# 87595  [Kathmandu Metropolitan City (KMC), in order t...       2
# 87596  [Kathmandu Metropolitan City (KMC), in order t...       2
# 87597  [Kathmandu Metropolitan City (KMC), in order t...       1
# 87598  [Kathmandu Metropolitan City (KMC), in order t...       0
#
#                                              answer text  \
# 0      It is a replica of the grotto at Lourdes, Fran...
# 1      Immediately in front of the Main Building and ...
# 2      Next to the Main Building is the Basilica of t...
# 3      Immediately behind the basilica is the Grotto,...
# 4      Atop the Main Building's gold dome is a golden...
# ...                                                  ...
# 87594  KMC's first international relationship was est...
# 87595  This activity has been further enhanced by est...
# 87596  This activity has been further enhanced by est...
# 87597  KMC's first international relationship was est...
# 87598  Kathmandu Metropolitan City (KMC), in order to...
#
#                                        question_word2vec  \
# 0      [0.04432763, 0.05114068, 0.025661893, 0.027520...
# 1      [0.053157806, 0.030845642, 0.10076904, 0.05203...
# 2      [0.07283991, 0.03819691, 0.12393466, 0.1254106...
# 3      [0.05777486, 0.10460409, 0.13729858, 0.0961710...
# 4      [0.0009358724, 0.013122559, 0.124565974, 0.051...
# ...                                                  ...
# 87594  [0.0033081055, 0.057928465, 0.058052063, 0.067...
# 87595  [-0.024749756, -0.01738739, 0.10687256, 0.0566...
# 87596  [0.017283121, 0.0051574707, 0.08671061, 0.0952...
# 87597  [0.019544814, 0.08488634, 0.08759393, 0.062188...
# 87598  [0.08238983, -0.031570435, 0.11446953, 0.09390...
#
#                                          answer_word2vec
# 0      [0.07558136, 0.047441483, 0.050408937, 0.11994...
# 1      [0.07821013, 0.036659643, 0.03910346, 0.070101...
# 2      [0.1040819, 0.022325303, 0.123535156, 0.070712...
# 3      [0.07532077, -0.003913032, 0.119249135, 0.0689...
# 4      [0.03282089, 0.09317627, 0.05167236, 0.0454956...
# ...                                                  ...
# 87594  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 87595  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 87596  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 87597  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 87598  [-0.03152466, 0.10537284, 0.07245091, 0.007664...
#
# [87599 rows x 9 columns]

# %%
import ast

# %%
data = data[data["sentences"].str.len() < 11].reset_index(drop=True)

# %%
len(data)
# Out:
# 85120

# %%
def cosine_sim(x):
    li = []
    for item in x["sent_emb"]:
        li.append(spatial.distance.cosine(item,x["quest_emb"][0]))
    return li

# %%
def pred_idx(distances):
    return np.argmin(distances)

# %%
def embed_list_of_strings(lst, model):
    return [embed_text(sentence, model) for sentence in lst]

# %%
data['sent_emb'] = data['sentences'].apply(lambda x: embed_list_of_strings(x, word2vec_model))

# %%
data
# Out:
#                                                  context  \
# 0      Architecturally, the school has a Catholic cha...
# 1      Architecturally, the school has a Catholic cha...
# 2      Architecturally, the school has a Catholic cha...
# 3      Architecturally, the school has a Catholic cha...
# 4      Architecturally, the school has a Catholic cha...
# ...                                                  ...
# 85115  Kathmandu Metropolitan City (KMC), in order to...
# 85116  Kathmandu Metropolitan City (KMC), in order to...
# 85117  Kathmandu Metropolitan City (KMC), in order to...
# 85118  Kathmandu Metropolitan City (KMC), in order to...
# 85119  Kathmandu Metropolitan City (KMC), in order to...
#
#                                                 question  answer_start  \
# 0      To whom did the Virgin Mary allegedly appear i...           515
# 1      What is in front of the Notre Dame Main Building?           188
# 2      The Basilica of the Sacred heart at Notre Dame...           279
# 3                      What is the Grotto at Notre Dame?           381
# 4      What sits on top of the Main Building at Notre...            92
# ...                                                  ...           ...
# 85115  In what US state did Kathmandu first establish...           229
# 85116               What was Yangon previously known as?           414
# 85117  With what Belorussian city does Kathmandu have...           476
# 85118  In what year did Kathmandu create its initial ...           199
# 85119                      What is KMC an initialism of?             0
#
#                                           text  \
# 0                   Saint Bernadette Soubirous
# 1                    a copper statue of Christ
# 2                            the Main Building
# 3      a Marian place of prayer and reflection
# 4           a golden statue of the Virgin Mary
# ...                                        ...
# 85115                                   Oregon
# 85116                                  Rangoon
# 85117                                    Minsk
# 85118                                     1975
# 85119              Kathmandu Metropolitan City
#
#                                                sentences  target  \
# 0      [Architecturally, the school has a Catholic ch...       5
# 1      [Architecturally, the school has a Catholic ch...       2
# 2      [Architecturally, the school has a Catholic ch...       3
# 3      [Architecturally, the school has a Catholic ch...       4
# 4      [Architecturally, the school has a Catholic ch...       1
# ...                                                  ...     ...
# 85115  [Kathmandu Metropolitan City (KMC), in order t...       1
# 85116  [Kathmandu Metropolitan City (KMC), in order t...       2
# 85117  [Kathmandu Metropolitan City (KMC), in order t...       2
# 85118  [Kathmandu Metropolitan City (KMC), in order t...       1
# 85119  [Kathmandu Metropolitan City (KMC), in order t...       0
#
#                                              answer text  \
# 0      It is a replica of the grotto at Lourdes, Fran...
# 1      Immediately in front of the Main Building and ...
# 2      Next to the Main Building is the Basilica of t...
# 3      Immediately behind the basilica is the Grotto,...
# 4      Atop the Main Building's gold dome is a golden...
# ...                                                  ...
# 85115  KMC's first international relationship was est...
# 85116  This activity has been further enhanced by est...
# 85117  This activity has been further enhanced by est...
# 85118  KMC's first international relationship was est...
# 85119  Kathmandu Metropolitan City (KMC), in order to...
#
#                                        question_word2vec  \
# 0      [0.04432763, 0.05114068, 0.025661893, 0.027520...
# 1      [0.053157806, 0.030845642, 0.10076904, 0.05203...
# 2      [0.07283991, 0.03819691, 0.12393466, 0.1254106...
# 3      [0.05777486, 0.10460409, 0.13729858, 0.0961710...
# 4      [0.0009358724, 0.013122559, 0.124565974, 0.051...
# ...                                                  ...
# 85115  [0.0033081055, 0.057928465, 0.058052063, 0.067...
# 85116  [-0.024749756, -0.01738739, 0.10687256, 0.0566...
# 85117  [0.017283121, 0.0051574707, 0.08671061, 0.0952...
# 85118  [0.019544814, 0.08488634, 0.08759393, 0.062188...
# 85119  [0.08238983, -0.031570435, 0.11446953, 0.09390...
#
#                                          answer_word2vec  \
# 0      [0.07558136, 0.047441483, 0.050408937, 0.11994...
# 1      [0.07821013, 0.036659643, 0.03910346, 0.070101...
# 2      [0.1040819, 0.022325303, 0.123535156, 0.070712...
# 3      [0.07532077, -0.003913032, 0.119249135, 0.0689...
# 4      [0.03282089, 0.09317627, 0.05167236, 0.0454956...
# ...                                                  ...
# 85115  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 85116  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 85117  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 85118  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 85119  [-0.03152466, 0.10537284, 0.07245091, 0.007664...
#
#                                                 sent_emb
# 0      [[0.08312988, 0.02627182, 0.11063385, 0.193359...
# 1      [[0.08312988, 0.02627182, 0.11063385, 0.193359...
# 2      [[0.08312988, 0.02627182, 0.11063385, 0.193359...
# 3      [[0.08312988, 0.02627182, 0.11063385, 0.193359...
# 4      [[0.08312988, 0.02627182, 0.11063385, 0.193359...
# ...                                                  ...
# 85115  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...
# 85116  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...
# 85117  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...
# 85118  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...
# 85119  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...
#
# [85120 rows x 10 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
def compute_cosine_similarity(embedding1, embedding2):
    if embedding1 is None or embedding2 is None:
        return None
    else:
        return cosine_similarity([embedding1], [embedding2])[0]

# %%
for i, row in data.iterrows():
    question_embedding = row['question_word2vec']
    sent_embeddings = row['sent_emb']
    for j, sent_embedding in enumerate(sent_embeddings):
        # Compute cosine similarity between question_embedding and each sent_embedding
        cosine_sim = compute_cosine_similarity(question_embedding, sent_embedding)
        # Add the cosine similarity to a new column
        data.at[i, f'cos{j}'] = cosine_sim

# %%
data
# Out:
#                                                  context  \
# 0      Architecturally, the school has a Catholic cha...
# 1      Architecturally, the school has a Catholic cha...
# 2      Architecturally, the school has a Catholic cha...
# 3      Architecturally, the school has a Catholic cha...
# 4      Architecturally, the school has a Catholic cha...
# ...                                                  ...
# 85115  Kathmandu Metropolitan City (KMC), in order to...
# 85116  Kathmandu Metropolitan City (KMC), in order to...
# 85117  Kathmandu Metropolitan City (KMC), in order to...
# 85118  Kathmandu Metropolitan City (KMC), in order to...
# 85119  Kathmandu Metropolitan City (KMC), in order to...
#
#                                                 question  answer_start  \
# 0      To whom did the Virgin Mary allegedly appear i...           515
# 1      What is in front of the Notre Dame Main Building?           188
# 2      The Basilica of the Sacred heart at Notre Dame...           279
# 3                      What is the Grotto at Notre Dame?           381
# 4      What sits on top of the Main Building at Notre...            92
# ...                                                  ...           ...
# 85115  In what US state did Kathmandu first establish...           229
# 85116               What was Yangon previously known as?           414
# 85117  With what Belorussian city does Kathmandu have...           476
# 85118  In what year did Kathmandu create its initial ...           199
# 85119                      What is KMC an initialism of?             0
#
#                                           text  \
# 0                   Saint Bernadette Soubirous
# 1                    a copper statue of Christ
# 2                            the Main Building
# 3      a Marian place of prayer and reflection
# 4           a golden statue of the Virgin Mary
# ...                                        ...
# 85115                                   Oregon
# 85116                                  Rangoon
# 85117                                    Minsk
# 85118                                     1975
# 85119              Kathmandu Metropolitan City
#
#                                                sentences  target  \
# 0      [Architecturally, the school has a Catholic ch...       5
# 1      [Architecturally, the school has a Catholic ch...       2
# 2      [Architecturally, the school has a Catholic ch...       3
# 3      [Architecturally, the school has a Catholic ch...       4
# 4      [Architecturally, the school has a Catholic ch...       1
# ...                                                  ...     ...
# 85115  [Kathmandu Metropolitan City (KMC), in order t...       1
# 85116  [Kathmandu Metropolitan City (KMC), in order t...       2
# 85117  [Kathmandu Metropolitan City (KMC), in order t...       2
# 85118  [Kathmandu Metropolitan City (KMC), in order t...       1
# 85119  [Kathmandu Metropolitan City (KMC), in order t...       0
#
#                                              answer text  \
# 0      It is a replica of the grotto at Lourdes, Fran...
# 1      Immediately in front of the Main Building and ...
# 2      Next to the Main Building is the Basilica of t...
# 3      Immediately behind the basilica is the Grotto,...
# 4      Atop the Main Building's gold dome is a golden...
# ...                                                  ...
# 85115  KMC's first international relationship was est...
# 85116  This activity has been further enhanced by est...
# 85117  This activity has been further enhanced by est...
# 85118  KMC's first international relationship was est...
# 85119  Kathmandu Metropolitan City (KMC), in order to...
#
#                                        question_word2vec  \
# 0      [0.04432763, 0.05114068, 0.025661893, 0.027520...
# 1      [0.053157806, 0.030845642, 0.10076904, 0.05203...
# 2      [0.07283991, 0.03819691, 0.12393466, 0.1254106...
# 3      [0.05777486, 0.10460409, 0.13729858, 0.0961710...
# 4      [0.0009358724, 0.013122559, 0.124565974, 0.051...
# ...                                                  ...
# 85115  [0.0033081055, 0.057928465, 0.058052063, 0.067...
# 85116  [-0.024749756, -0.01738739, 0.10687256, 0.0566...
# 85117  [0.017283121, 0.0051574707, 0.08671061, 0.0952...
# 85118  [0.019544814, 0.08488634, 0.08759393, 0.062188...
# 85119  [0.08238983, -0.031570435, 0.11446953, 0.09390...
#
#                                          answer_word2vec  \
# 0      [0.07558136, 0.047441483, 0.050408937, 0.11994...
# 1      [0.07821013, 0.036659643, 0.03910346, 0.070101...
# 2      [0.1040819, 0.022325303, 0.123535156, 0.070712...
# 3      [0.07532077, -0.003913032, 0.119249135, 0.0689...
# 4      [0.03282089, 0.09317627, 0.05167236, 0.0454956...
# ...                                                  ...
# 85115  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 85116  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 85117  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 85118  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 85119  [-0.03152466, 0.10537284, 0.07245091, 0.007664...
#
#                                                 sent_emb      cos0      cos1  \
# 0      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  0.431621  0.472877
# 1      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  0.369423  0.554328
# 2      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  0.420924  0.627810
# 3      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  0.409562  0.557070
# 4      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  0.344913  0.578154
# ...                                                  ...       ...       ...
# 85115  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  0.636493  0.754431
# 85116  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  0.299827  0.485796
# 85117  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  0.466352  0.593181
# 85118  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  0.597686  0.708139
# 85119  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  0.299768  0.372463
#
#            cos2      cos3      cos4      cos5      cos6  cos7  cos8  cos9
# 0      0.564637  0.421326  0.425999  0.705260  0.524225   NaN   NaN   NaN
# 1      0.632660  0.599598  0.513503  0.625822  0.621614   NaN   NaN   NaN
# 2      0.638587  0.777642  0.726845  0.743519  0.619731   NaN   NaN   NaN
# 3      0.542247  0.638662  0.615400  0.777871  0.573276   NaN   NaN   NaN
# 4      0.618867  0.697404  0.579587  0.542959  0.658568   NaN   NaN   NaN
# ...         ...       ...       ...       ...       ...   ...   ...   ...
# 85115  0.672387  0.630387       NaN       NaN       NaN   NaN   NaN   NaN
# 85116  0.441521  0.375872       NaN       NaN       NaN   NaN   NaN   NaN
# 85117  0.614880  0.580059       NaN       NaN       NaN   NaN   NaN   NaN
# 85118  0.659406  0.658406       NaN       NaN       NaN   NaN   NaN   NaN
# 85119  0.466039  0.383690       NaN       NaN       NaN   NaN   NaN   NaN
#
# [85120 rows x 20 columns]

# %%
def compute_euclidean_distance(embedding1, embedding2):
    if embedding1 is None or embedding2 is None:
        return None
    else:
        return np.linalg.norm(embedding1 - embedding2)

# %%
for i, row in data.iterrows():
    question_embedding = row['question_word2vec']
    sent_embeddings = row['sent_emb']
    for j, sent_embedding in enumerate(sent_embeddings):
        # Compute Euclidean distance between question_embedding and each sent_embedding
        euclidean_dist = compute_euclidean_distance(question_embedding, sent_embedding)
        # Add the Euclidean distance to a new column
        data.at[i, f'euclidean{j}'] = euclidean_dist

# %%
data
# Out:
#                                                  context  \
# 0      Architecturally, the school has a Catholic cha...
# 1      Architecturally, the school has a Catholic cha...
# 2      Architecturally, the school has a Catholic cha...
# 3      Architecturally, the school has a Catholic cha...
# 4      Architecturally, the school has a Catholic cha...
# ...                                                  ...
# 85115  Kathmandu Metropolitan City (KMC), in order to...
# 85116  Kathmandu Metropolitan City (KMC), in order to...
# 85117  Kathmandu Metropolitan City (KMC), in order to...
# 85118  Kathmandu Metropolitan City (KMC), in order to...
# 85119  Kathmandu Metropolitan City (KMC), in order to...
#
#                                                 question  answer_start  \
# 0      To whom did the Virgin Mary allegedly appear i...           515
# 1      What is in front of the Notre Dame Main Building?           188
# 2      The Basilica of the Sacred heart at Notre Dame...           279
# 3                      What is the Grotto at Notre Dame?           381
# 4      What sits on top of the Main Building at Notre...            92
# ...                                                  ...           ...
# 85115  In what US state did Kathmandu first establish...           229
# 85116               What was Yangon previously known as?           414
# 85117  With what Belorussian city does Kathmandu have...           476
# 85118  In what year did Kathmandu create its initial ...           199
# 85119                      What is KMC an initialism of?             0
#
#                                           text  \
# 0                   Saint Bernadette Soubirous
# 1                    a copper statue of Christ
# 2                            the Main Building
# 3      a Marian place of prayer and reflection
# 4           a golden statue of the Virgin Mary
# ...                                        ...
# 85115                                   Oregon
# 85116                                  Rangoon
# 85117                                    Minsk
# 85118                                     1975
# 85119              Kathmandu Metropolitan City
#
#                                                sentences  target  \
# 0      [Architecturally, the school has a Catholic ch...       5
# 1      [Architecturally, the school has a Catholic ch...       2
# 2      [Architecturally, the school has a Catholic ch...       3
# 3      [Architecturally, the school has a Catholic ch...       4
# 4      [Architecturally, the school has a Catholic ch...       1
# ...                                                  ...     ...
# 85115  [Kathmandu Metropolitan City (KMC), in order t...       1
# 85116  [Kathmandu Metropolitan City (KMC), in order t...       2
# 85117  [Kathmandu Metropolitan City (KMC), in order t...       2
# 85118  [Kathmandu Metropolitan City (KMC), in order t...       1
# 85119  [Kathmandu Metropolitan City (KMC), in order t...       0
#
#                                              answer text  \
# 0      It is a replica of the grotto at Lourdes, Fran...
# 1      Immediately in front of the Main Building and ...
# 2      Next to the Main Building is the Basilica of t...
# 3      Immediately behind the basilica is the Grotto,...
# 4      Atop the Main Building's gold dome is a golden...
# ...                                                  ...
# 85115  KMC's first international relationship was est...
# 85116  This activity has been further enhanced by est...
# 85117  This activity has been further enhanced by est...
# 85118  KMC's first international relationship was est...
# 85119  Kathmandu Metropolitan City (KMC), in order to...
#
#                                        question_word2vec  \
# 0      [0.04432763, 0.05114068, 0.025661893, 0.027520...
# 1      [0.053157806, 0.030845642, 0.10076904, 0.05203...
# 2      [0.07283991, 0.03819691, 0.12393466, 0.1254106...
# 3      [0.05777486, 0.10460409, 0.13729858, 0.0961710...
# 4      [0.0009358724, 0.013122559, 0.124565974, 0.051...
# ...                                                  ...
# 85115  [0.0033081055, 0.057928465, 0.058052063, 0.067...
# 85116  [-0.024749756, -0.01738739, 0.10687256, 0.0566...
# 85117  [0.017283121, 0.0051574707, 0.08671061, 0.0952...
# 85118  [0.019544814, 0.08488634, 0.08759393, 0.062188...
# 85119  [0.08238983, -0.031570435, 0.11446953, 0.09390...
#
#                                          answer_word2vec  \
# 0      [0.07558136, 0.047441483, 0.050408937, 0.11994...
# 1      [0.07821013, 0.036659643, 0.03910346, 0.070101...
# 2      [0.1040819, 0.022325303, 0.123535156, 0.070712...
# 3      [0.07532077, -0.003913032, 0.119249135, 0.0689...
# 4      [0.03282089, 0.09317627, 0.05167236, 0.0454956...
# ...                                                  ...
# 85115  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 85116  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 85117  [-0.02366222, 0.006723577, 0.008219112, 0.1252...
# 85118  [-0.02399292, 0.06692505, 0.0375, 0.056396484,...
# 85119  [-0.03152466, 0.10537284, 0.07245091, 0.007664...
#
#                                                 sent_emb  ...  euclidean0  \
# 0      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  ...    1.296807
# 1      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  ...    1.389548
# 2      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  ...    1.355416
# 3      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  ...    1.386715
# 4      [[0.08312988, 0.02627182, 0.11063385, 0.193359...  ...    1.393793
# ...                                                  ...  ...         ...
# 85115  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  ...    0.873747
# 85116  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  ...    1.392376
# 85117  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  ...    1.067820
# 85118  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  ...    0.910435
# 85119  [[-0.03152466, 0.10537284, 0.07245091, 0.00766...  ...    1.352517
#
#        euclidean1  euclidean2  euclidean3  euclidean4  euclidean5  euclidean6  \
# 0        1.176548    0.923805    1.185900    1.144119    0.807753    0.951149
# 1        1.108372    0.885345    1.014190    1.085253    0.938403    0.888404
# 2        1.032379    0.908919    0.772131    0.833630    0.798622    0.922944
# 3        1.142865    1.043907    1.001641    1.008912    0.761802    1.001150
# 4        1.062279    0.874101    0.867809    0.987312    1.013277    0.817541
# ...           ...         ...         ...         ...         ...         ...
# 85115    0.666640    0.727949    0.814696         NaN         NaN         NaN
# 85116    1.152521    1.165259    1.260769         NaN         NaN         NaN
# 85117    0.872944    0.807602    0.884282         NaN         NaN         NaN
# 85118    0.718573    0.730262    0.774187         NaN         NaN         NaN
# 85119    1.223973    1.097490    1.210927         NaN         NaN         NaN
#
#        euclidean7  euclidean8  euclidean9
# 0             NaN         NaN         NaN
# 1             NaN         NaN         NaN
# 2             NaN         NaN         NaN
# 3             NaN         NaN         NaN
# 4             NaN         NaN         NaN
# ...           ...         ...         ...
# 85115         NaN         NaN         NaN
# 85116         NaN         NaN         NaN
# 85117         NaN         NaN         NaN
# 85118         NaN         NaN         NaN
# 85119         NaN         NaN         NaN
#
# [85120 rows x 30 columns]

# %%
selected_columns = ['target',
       'cos0', 'cos1', 'cos2', 'cos3', 'cos4', 'cos5', 'cos6', 'cos7', 'cos8',
       'cos9', 'euclidean0', 'euclidean1', 'euclidean2', 'euclidean3',
       'euclidean4', 'euclidean5', 'euclidean6', 'euclidean7', 'euclidean8',
       'euclidean9']

# %%
train = data.loc[:, selected_columns]

# %%
train
# Out:
#        target      cos0      cos1      cos2      cos3      cos4      cos5  \
# 0           5  0.431621  0.472877  0.564637  0.421326  0.425999  0.705260
# 1           2  0.369423  0.554328  0.632660  0.599598  0.513503  0.625822
# 2           3  0.420924  0.627810  0.638587  0.777642  0.726845  0.743519
# 3           4  0.409562  0.557070  0.542247  0.638662  0.615400  0.777871
# 4           1  0.344913  0.578154  0.618867  0.697404  0.579587  0.542959
# ...       ...       ...       ...       ...       ...       ...       ...
# 85115       1  0.636493  0.754431  0.672387  0.630387       NaN       NaN
# 85116       2  0.299827  0.485796  0.441521  0.375872       NaN       NaN
# 85117       2  0.466352  0.593181  0.614880  0.580059       NaN       NaN
# 85118       1  0.597686  0.708139  0.659406  0.658406       NaN       NaN
# 85119       0  0.299768  0.372463  0.466039  0.383690       NaN       NaN
#
#            cos6  cos7  cos8  ...  euclidean0  euclidean1  euclidean2  \
# 0      0.524225   NaN   NaN  ...    1.296807    1.176548    0.923805
# 1      0.621614   NaN   NaN  ...    1.389548    1.108372    0.885345
# 2      0.619731   NaN   NaN  ...    1.355416    1.032379    0.908919
# 3      0.573276   NaN   NaN  ...    1.386715    1.142865    1.043907
# 4      0.658568   NaN   NaN  ...    1.393793    1.062279    0.874101
# ...         ...   ...   ...  ...         ...         ...         ...
# 85115       NaN   NaN   NaN  ...    0.873747    0.666640    0.727949
# 85116       NaN   NaN   NaN  ...    1.392376    1.152521    1.165259
# 85117       NaN   NaN   NaN  ...    1.067820    0.872944    0.807602
# 85118       NaN   NaN   NaN  ...    0.910435    0.718573    0.730262
# 85119       NaN   NaN   NaN  ...    1.352517    1.223973    1.097490
#
#        euclidean3  euclidean4  euclidean5  euclidean6  euclidean7  euclidean8  \
# 0        1.185900    1.144119    0.807753    0.951149         NaN         NaN
# 1        1.014190    1.085253    0.938403    0.888404         NaN         NaN
# 2        0.772131    0.833630    0.798622    0.922944         NaN         NaN
# 3        1.001641    1.008912    0.761802    1.001150         NaN         NaN
# 4        0.867809    0.987312    1.013277    0.817541         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 85115    0.814696         NaN         NaN         NaN         NaN         NaN
# 85116    1.260769         NaN         NaN         NaN         NaN         NaN
# 85117    0.884282         NaN         NaN         NaN         NaN         NaN
# 85118    0.774187         NaN         NaN         NaN         NaN         NaN
# 85119    1.210927         NaN         NaN         NaN         NaN         NaN
#
#        euclidean9
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 85115         NaN
# 85116         NaN
# 85117         NaN
# 85118         NaN
# 85119         NaN
#
# [85120 rows x 21 columns]

# %%
subset1 = train.iloc[:,:10].fillna(0)
subset2 = train.iloc[:,10:].fillna(60)

# %%
train2 = pd.concat([subset1, subset2], axis=1)

# %%
train2
# Out:
#        target      cos0      cos1      cos2      cos3      cos4      cos5  \
# 0           5  0.431621  0.472877  0.564637  0.421326  0.425999  0.705260
# 1           2  0.369423  0.554328  0.632660  0.599598  0.513503  0.625822
# 2           3  0.420924  0.627810  0.638587  0.777642  0.726845  0.743519
# 3           4  0.409562  0.557070  0.542247  0.638662  0.615400  0.777871
# 4           1  0.344913  0.578154  0.618867  0.697404  0.579587  0.542959
# ...       ...       ...       ...       ...       ...       ...       ...
# 85115       1  0.636493  0.754431  0.672387  0.630387  0.000000  0.000000
# 85116       2  0.299827  0.485796  0.441521  0.375872  0.000000  0.000000
# 85117       2  0.466352  0.593181  0.614880  0.580059  0.000000  0.000000
# 85118       1  0.597686  0.708139  0.659406  0.658406  0.000000  0.000000
# 85119       0  0.299768  0.372463  0.466039  0.383690  0.000000  0.000000
#
#            cos6  cos7  cos8  ...  euclidean0  euclidean1  euclidean2  \
# 0      0.524225   0.0   0.0  ...    1.296807    1.176548    0.923805
# 1      0.621614   0.0   0.0  ...    1.389548    1.108372    0.885345
# 2      0.619731   0.0   0.0  ...    1.355416    1.032379    0.908919
# 3      0.573276   0.0   0.0  ...    1.386715    1.142865    1.043907
# 4      0.658568   0.0   0.0  ...    1.393793    1.062279    0.874101
# ...         ...   ...   ...  ...         ...         ...         ...
# 85115  0.000000   0.0   0.0  ...    0.873747    0.666640    0.727949
# 85116  0.000000   0.0   0.0  ...    1.392376    1.152521    1.165259
# 85117  0.000000   0.0   0.0  ...    1.067820    0.872944    0.807602
# 85118  0.000000   0.0   0.0  ...    0.910435    0.718573    0.730262
# 85119  0.000000   0.0   0.0  ...    1.352517    1.223973    1.097490
#
#        euclidean3  euclidean4  euclidean5  euclidean6  euclidean7  euclidean8  \
# 0        1.185900    1.144119    0.807753    0.951149        60.0        60.0
# 1        1.014190    1.085253    0.938403    0.888404        60.0        60.0
# 2        0.772131    0.833630    0.798622    0.922944        60.0        60.0
# 3        1.001641    1.008912    0.761802    1.001150        60.0        60.0
# 4        0.867809    0.987312    1.013277    0.817541        60.0        60.0
# ...           ...         ...         ...         ...         ...         ...
# 85115    0.814696   60.000000   60.000000   60.000000        60.0        60.0
# 85116    1.260769   60.000000   60.000000   60.000000        60.0        60.0
# 85117    0.884282   60.000000   60.000000   60.000000        60.0        60.0
# 85118    0.774187   60.000000   60.000000   60.000000        60.0        60.0
# 85119    1.210927   60.000000   60.000000   60.000000        60.0        60.0
#
#        euclidean9
# 0            60.0
# 1            60.0
# 2            60.0
# 3            60.0
# 4            60.0
# ...           ...
# 85115        60.0
# 85116        60.0
# 85117        60.0
# 85118        60.0
# 85119        60.0
#
# [85120 rows x 21 columns]

# %%
train2.apply(max, axis = 0)
# Out:
# target         9.000000
# cos0           1.000000
# cos1           1.000000
# cos2           1.000000
# cos3           1.000000
# cos4           1.000000
# cos5           0.997890
# cos6           0.980326
# cos7           0.979544
# cos8           0.985612
# cos9          60.000000
# euclidean0    60.000000
# euclidean1    60.000000
# euclidean2    60.000000
# euclidean3    60.000000
# euclidean4    60.000000
# euclidean5    60.000000
# euclidean6    60.000000
# euclidean7    60.000000
# euclidean8    60.000000
# euclidean9    60.000000
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(train2.iloc[:,1:])

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(X,
train.iloc[:,0], train_size=0.8, random_state = 5)

# %%
train_x.shape
# Out:
# (68096, 20)

# %%
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn import linear_model
from sklearn import metrics

# %%
mul_lr = linear_model.LogisticRegression(multi_class='multinomial', solver='newton-cg')
mul_lr.fit(train_x, train_y)

print("Multinomial Logistic regression Train Accuracy : ", metrics.accuracy_score(train_y, mul_lr.predict(train_x)))
print("Multinomial Logistic regression Test Accuracy : ", metrics.accuracy_score(test_y, mul_lr.predict(test_x)))
# Out:
# Multinomial Logistic regression Train Accuracy :  0.647703242481203
# Multinomial Logistic regression Test Accuracy :  0.6544290413533834

# %%
context="Mount Everest, also known as Sagarmatha in Nepal and Chomolungma in Tibet, is Earth's highest mountain above sea level, located in the Mahalangur Himal sub-range of the Himalayas. Its peak is 8,848.86 meters (29,031.7 feet) above sea level, making it one of the Seven Summits. The international border between China and Nepal runs across Everest's precise summit point."

# %%
question="What is the height of Mount Everest above sea level?"

# %%
blob = TextBlob(context)
sentences = blob.sentences
sentences_list = [str(sentence) for sentence in sentences]
print(len(sentences_list))
# Out:
# 3

# %%
def embed_text_list(list_of_strings, model):
    embeddings = []
    for text in list_of_strings:
        embedding = embed_text(text, model)
        embeddings.append(embedding)
    return embeddings

# %%
sentences_embeddings = embed_text_list(sentences_list, word2vec_model)

# %%
quest_emb=embed_text(question, word2vec_model)

# %%
def compute_cosine_similarity(separate_array, array_list):
    similarities = []
    for array in array_list:
        similarity = cosine_similarity([separate_array], [array])[0][0]
        similarities.append(similarity)
    return similarities

# %%
cossimilarities = compute_cosine_similarity(quest_emb, sentences_embeddings)

# %%
def compute_euclidean_distances(separate_array, array_list):
    distances = []
    for array in array_list:
        distance = np.linalg.norm(separate_array - array)
        distances.append(distance)
    return distances

# %%
euc_dist=compute_euclidean_distances(quest_emb, sentences_embeddings)

# %%
def pad_list(l1,l2):
    while len(l1) <10:
        l1.append(0)
        l2.append(60)
    return l1 , l2

# %%
cossim , euc = pad_list(cossimilarities, euc_dist)

# %%
p = cossim + euc

# %%
predictions = mul_lr.predict([p])
print(predictions)
# Out:
# [1]

# %%
sentences_list
# Out:
# ["Mount Everest, also known as Sagarmatha in Nepal and Chomolungma in Tibet, is Earth's highest mountain above sea level, located in the Mahalangur Himal sub-range of the Himalayas.",
#  'Its peak is 8,848.86 meters (29,031.7 feet) above sea level, making it one of the Seven Summits.',
#  "The international border between China and Nepal runs across Everest's precise summit point."]

# %%
question
# Out:
# 'What is the height of Mount Everest above sea level?'

# %%
context
# Out:
# "Mount Everest, also known as Sagarmatha in Nepal and Chomolungma in Tibet, is Earth's highest mountain above sea level, located in the Mahalangur Himal sub-range of the Himalayas. Its peak is 8,848.86 meters (29,031.7 feet) above sea level, making it one of the Seven Summits. The international border between China and Nepal runs across Everest's precise summit point."
